# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Flow_Time_1902 = pd.read_csv("./4개지역_FLOW_TIME_201902.CSV",sep="|")
Flow_Time_1903 = pd.read_csv("./4개지역_FLOW_TIME_201903.CSV",sep="|")
Flow_Time_1904 = pd.read_csv("./4개지역_FLOW_TIME_201904.CSV",sep="|")
Flow_Time_1905 = pd.read_csv("./4개지역_FLOW_TIME_201905.CSV",sep="|")

Flow_Time_2002 = pd.read_csv("./4개지역_FLOW_TIME_202002.CSV",sep="|")
Flow_Time_2003 = pd.read_csv("./4개지역_FLOW_TIME_202003.CSV",sep="|")
Flow_Time_2004 = pd.read_csv("./4개지역_FLOW_TIME_202004.CSV",sep="|")
Flow_Time_2005 = pd.read_csv("./4개지역_FLOW_TIME_202005.CSV",sep="|")

# %%
ex = Flow_Time_2005['HDONG_NM'].unique().tolist()
len(ex)
# 각 파일 다 행정동 수 같음
# Out:
# 69

# %%
Flow_Time_2002.head(69)
# Out:
#     STD_YM   STD_YMD    HDONG_CD HDONG_NM  TMST_00  TMST_01  TMST_02  TMST_03  \
# 0   202002  20200201  1114052000      소공동  1393.34  1144.91   900.51   721.78
# 1   202002  20200201  1114054000      회현동  1586.96  1170.81   898.06   682.55
# 2   202002  20200201  1114055000       명동  1534.52  1139.65  1015.20   799.85
# 3   202002  20200201  1114057000       필동  1321.52   933.49   803.40   690.18
# 4   202002  20200201  1114058000      장충동   629.17   561.68   454.77   372.22
# ..     ...       ...         ...      ...      ...      ...      ...      ...
# 64  202002  20200201  2726066100     범물1동   651.70   644.62   494.25   440.50
# 65  202002  20200201  2726066200     범물2동   892.80   917.63   858.43   786.57
# 66  202002  20200201  2726067000     고산1동  2436.67  2464.22  1850.57  1459.93
# 67  202002  20200201  2726068000     고산2동  3345.41  3242.01  2597.22  1984.21
# 68  202002  20200201  2726069000     고산3동   925.69   990.90   825.64   608.13
#
#     TMST_04  TMST_05  ...   TMST_14   TMST_15   TMST_16   TMST_17   TMST_18  \
# 0    784.43  1479.50  ...   7705.97   7389.93   7322.32   8070.40   6488.70
# 1    763.84  2089.57  ...  11846.92  11701.47  11364.08  10725.66   8140.20
# 2    773.06  1506.43  ...  11188.64  10109.60  10587.30  10697.87   8781.11
# 3    754.61   954.29  ...   4931.33   4989.49   5010.95   5702.29   5089.43
# 4    388.65   627.47  ...   3423.15   3030.29   2882.15   3099.08   2584.95
# ..      ...      ...  ...       ...       ...       ...       ...       ...
# 64   426.99   432.40  ...   2723.06   2564.26   2587.08   2891.00   2643.08
# 65   785.69   790.97  ...   1424.13   1407.24   1453.00   1564.13   1618.15
# 66  1233.43  1440.21  ...   8345.96   8226.55   8681.83   8932.43   9406.29
# 67  1776.61  2141.22  ...  15692.30  15946.11  16513.72  16833.45  15738.31
# 68   525.01   552.17  ...   2975.43   3064.66   3149.38   3299.51   3386.96
#
#      TMST_19   TMST_20   TMST_21  TMST_22  TMST_23
# 0    4890.46   4304.38   3683.57  4002.98  2894.37
# 1    6399.03   5566.32   5533.92  4715.67  3334.92
# 2    6420.97   5091.03   5025.40  4415.18  3415.71
# 3    3959.67   3151.50   3048.29  2951.06  2017.30
# 4    1811.88   1669.96   1664.65  1164.56   976.00
# ..       ...       ...       ...      ...      ...
# 64   2048.94   1689.79   1584.89  1339.53  1069.77
# 65   1359.31   1276.74   1229.98  1173.76  1097.01
# 66   7977.51   6534.62   6013.44  5010.45  4019.01
# 67  12390.65  11199.83  10092.47  7631.40  6111.72
# 68   2922.31   2528.88   2438.62  1990.19  1637.63
#
# [69 rows x 28 columns]

# %%
import datetime

def make_weekday(x):
    
    week = ['월','화','수','목','금','토','일']

    day = datetime.datetime.strptime(str(x),'%Y%m%d').weekday()
    
    return week[day]

make_weekday(20190201)
# Out:
# '금'

# %%
Flow_Time_1902['STD_DAY'] = Flow_Time_1902["STD_YMD"].map(make_weekday)
Flow_Time_1903['STD_DAY'] = Flow_Time_1903["STD_YMD"].map(make_weekday)
Flow_Time_1904['STD_DAY'] = Flow_Time_1904["STD_YMD"].map(make_weekday)
Flow_Time_1905['STD_DAY'] = Flow_Time_1905["STD_YMD"].map(make_weekday)

Flow_Time_2002['STD_DAY'] = Flow_Time_2002["STD_YMD"].map(make_weekday)
Flow_Time_2003['STD_DAY'] = Flow_Time_2003["STD_YMD"].map(make_weekday)
Flow_Time_2004['STD_DAY'] = Flow_Time_2004["STD_YMD"].map(make_weekday)
Flow_Time_2005['STD_DAY'] = Flow_Time_2005["STD_YMD"].map(make_weekday)

Flow_Time_2002
# Out:
#       STD_YM   STD_YMD    HDONG_CD HDONG_NM  TMST_00  TMST_01  TMST_02  \
# 0     202002  20200201  1114052000      소공동  1393.34  1144.91   900.51
# 1     202002  20200201  1114054000      회현동  1586.96  1170.81   898.06
# 2     202002  20200201  1114055000       명동  1534.52  1139.65  1015.20
# 3     202002  20200201  1114057000       필동  1321.52   933.49   803.40
# 4     202002  20200201  1114058000      장충동   629.17   561.68   454.77
# ...      ...       ...         ...      ...      ...      ...      ...
# 1996  202002  20200229  2726066100     범물1동   485.96   388.68   348.90
# 1997  202002  20200229  2726066200     범물2동   947.07   896.23   851.62
# 1998  202002  20200229  2726067000     고산1동  2162.60  1758.41  1318.00
# 1999  202002  20200229  2726068000     고산2동  2599.19  2085.08  1549.93
# 2000  202002  20200229  2726069000     고산3동   953.12   774.17   597.53
#
#       TMST_03  TMST_04  TMST_05  ...   TMST_15   TMST_16   TMST_17   TMST_18  \
# 0      721.78   784.43  1479.50  ...   7389.93   7322.32   8070.40   6488.70
# 1      682.55   763.84  2089.57  ...  11701.47  11364.08  10725.66   8140.20
# 2      799.85   773.06  1506.43  ...  10109.60  10587.30  10697.87   8781.11
# 3      690.18   754.61   954.29  ...   4989.49   5010.95   5702.29   5089.43
# 4      372.22   388.65   627.47  ...   3030.29   2882.15   3099.08   2584.95
# ...       ...      ...      ...  ...       ...       ...       ...       ...
# 1996   289.15   330.33   409.87  ...   1957.39   2093.72   2040.10   1849.73
# 1997   794.46   783.83   787.49  ...   1276.28   1296.90   1351.59   1351.30
# 1998  1203.27  1040.30  1184.69  ...   6474.89   6595.47   6772.06   6391.21
# 1999  1509.08  1406.71  1800.18  ...  11587.25  12424.47  11691.56  10228.67
# 2000   535.36   434.14   494.79  ...   2955.12   2881.20   3016.32   2952.53
#
#       TMST_19  TMST_20  TMST_21  TMST_22  TMST_23  STD_DAY
# 0     4890.46  4304.38  3683.57  4002.98  2894.37        토
# 1     6399.03  5566.32  5533.92  4715.67  3334.92        토
# 2     6420.97  5091.03  5025.40  4415.18  3415.71        토
# 3     3959.67  3151.50  3048.29  2951.06  2017.30        토
# 4     1811.88  1669.96  1664.65  1164.56   976.00        토
# ...       ...      ...      ...      ...      ...      ...
# 1996  1265.70  1041.32   905.75   712.61   628.77        토
# 1997  1246.78  1140.83  1108.22  1031.76  1024.64        토
# 1998  5232.65  4209.28  3874.91  3198.69  2708.60        토
# 1999  7664.57  6384.05  5682.11  4365.86  3399.61        토
# 2000  2327.83  1937.84  1745.39  1398.17  1227.13        토
#
# [2001 rows x 29 columns]

# %%
Flow_Time_1902['TMST_SUM'] = Flow_Time_1902[Flow_Time_1902.columns[4:28]].sum(axis=1)
Flow_Time_1903['TMST_SUM'] = Flow_Time_1903[Flow_Time_1903.columns[4:28]].sum(axis=1)
Flow_Time_1904['TMST_SUM'] = Flow_Time_1904[Flow_Time_1904.columns[4:28]].sum(axis=1)
Flow_Time_1905['TMST_SUM'] = Flow_Time_1905[Flow_Time_1905.columns[4:28]].sum(axis=1)

Flow_Time_2002['TMST_SUM'] = Flow_Time_2002[Flow_Time_2002.columns[4:28]].sum(axis=1)
Flow_Time_2003['TMST_SUM'] = Flow_Time_2003[Flow_Time_2003.columns[4:28]].sum(axis=1)
Flow_Time_2004['TMST_SUM'] = Flow_Time_2004[Flow_Time_2004.columns[4:28]].sum(axis=1)
Flow_Time_2005['TMST_SUM'] = Flow_Time_2005[Flow_Time_2005.columns[4:28]].sum(axis=1)

Flow_Time_2002
# Out:
#       STD_YM   STD_YMD    HDONG_CD HDONG_NM  TMST_00  TMST_01  TMST_02  \
# 0     202002  20200201  1114052000      소공동  1393.34  1144.91   900.51
# 1     202002  20200201  1114054000      회현동  1586.96  1170.81   898.06
# 2     202002  20200201  1114055000       명동  1534.52  1139.65  1015.20
# 3     202002  20200201  1114057000       필동  1321.52   933.49   803.40
# 4     202002  20200201  1114058000      장충동   629.17   561.68   454.77
# ...      ...       ...         ...      ...      ...      ...      ...
# 1996  202002  20200229  2726066100     범물1동   485.96   388.68   348.90
# 1997  202002  20200229  2726066200     범물2동   947.07   896.23   851.62
# 1998  202002  20200229  2726067000     고산1동  2162.60  1758.41  1318.00
# 1999  202002  20200229  2726068000     고산2동  2599.19  2085.08  1549.93
# 2000  202002  20200229  2726069000     고산3동   953.12   774.17   597.53
#
#       TMST_03  TMST_04  TMST_05  ...   TMST_16   TMST_17   TMST_18  TMST_19  \
# 0      721.78   784.43  1479.50  ...   7322.32   8070.40   6488.70  4890.46
# 1      682.55   763.84  2089.57  ...  11364.08  10725.66   8140.20  6399.03
# 2      799.85   773.06  1506.43  ...  10587.30  10697.87   8781.11  6420.97
# 3      690.18   754.61   954.29  ...   5010.95   5702.29   5089.43  3959.67
# 4      372.22   388.65   627.47  ...   2882.15   3099.08   2584.95  1811.88
# ...       ...      ...      ...  ...       ...       ...       ...      ...
# 1996   289.15   330.33   409.87  ...   2093.72   2040.10   1849.73  1265.70
# 1997   794.46   783.83   787.49  ...   1296.90   1351.59   1351.30  1246.78
# 1998  1203.27  1040.30  1184.69  ...   6595.47   6772.06   6391.21  5232.65
# 1999  1509.08  1406.71  1800.18  ...  12424.47  11691.56  10228.67  7664.57
# 2000   535.36   434.14   494.79  ...   2881.20   3016.32   2952.53  2327.83
#
#       TMST_20  TMST_21  TMST_22  TMST_23  STD_DAY   TMST_SUM
# 0     4304.38  3683.57  4002.98  2894.37        토  111317.71
# 1     5566.32  5533.92  4715.67  3334.92        토  162786.03
# 2     5091.03  5025.40  4415.18  3415.71        토  150722.60
# 3     3151.50  3048.29  2951.06  2017.30        토   79537.57
# 4     1669.96  1664.65  1164.56   976.00        토   45601.21
# ...       ...      ...      ...      ...      ...        ...
# 1996  1041.32   905.75   712.61   628.77        토   26225.20
# 1997  1140.83  1108.22  1031.76  1024.64        토   26071.96
# 1998  4209.28  3874.91  3198.69  2708.60        토   93149.42
# 1999  6384.05  5682.11  4365.86  3399.61        토  152158.48
# 2000  1937.84  1745.39  1398.17  1227.13        토   40516.31
#
# [2001 rows x 30 columns]

# %%
# 8x4 형식의 그래프 만들기.
# x 축 : 시간대
# y 축 : 유동인구 수
# 각 특정 동에 대해서 나타내는 전체 표
# 한 그래프 당 일자 별을 나타냄

def Make_Time_HDONG(month, num_HD):
    
    HDONG = []
    
    if month == 1902:
        day = 28
        base_df = Flow_Time_1902
    elif month == 1903:
        day = 31
        base_df = Flow_Time_1903
    elif month == 1904:
        day = 30
        base_df = Flow_Time_1904
    elif month == 1905:
        day = 31
        base_df = Flow_Time_1905
    elif month == 2002:
        day = 29
        base_df = Flow_Time_2002
    elif month == 2003:
        day = 31
        base_df = Flow_Time_2003
    elif month == 2004:
        day = 30
        base_df = Flow_Time_2004
    elif month == 2005:
        day = 31
        base_df = Flow_Time_2005
    else:
        print("1902~1905, 2002~2005")
    num_hdong = 69
    sum_index = day * num_hdong
    
    base_df = base_df.sort_values(by=['HDONG_CD','STD_YMD'])
    base_df = base_df.reset_index()
    
    for index in range(0, sum_index, day):
        HDONG.append(base_df[index:index+day])
        
    return HDONG[num_HD]

# %%
cnpz = Make_Time_HDONG(2002, 0)
cnpz
# Out:
#     index  STD_YM   STD_YMD    HDONG_CD HDONG_NM  TMST_00  TMST_01  TMST_02  \
# 0       0  202002  20200201  1114052000      소공동  1393.34  1144.91   900.51
# 1      69  202002  20200202  1114052000      소공동  1299.71   855.61   640.30
# 2     138  202002  20200203  1114052000      소공동   928.15   618.43   488.75
# 3     207  202002  20200204  1114052000      소공동  1606.69   925.98   688.39
# 4     276  202002  20200205  1114052000      소공동  1602.91   905.50   681.57
# 5     345  202002  20200206  1114052000      소공동  1612.15   940.50   746.33
# 6     414  202002  20200207  1114052000      소공동  1765.84  1053.53   773.89
# 7     483  202002  20200208  1114052000      소공동  2060.83  1126.66   897.84
# 8     552  202002  20200209  1114052000      소공동  1213.64   813.36   675.85
# 9     621  202002  20200210  1114052000      소공동   874.54   619.64   503.53
# 10    690  202002  20200211  1114052000      소공동  1552.30   908.55   745.66
# 11    759  202002  20200212  1114052000      소공동  1679.81  1001.35   843.91
# 12    828  202002  20200213  1114052000      소공동  1606.35  1022.35   782.90
# 13    897  202002  20200214  1114052000      소공동  1818.67  1123.02   818.38
# 14    966  202002  20200215  1114052000      소공동  2051.95  1094.09   865.89
# 15   1035  202002  20200216  1114052000      소공동  1217.02   769.81   683.93
# 16   1104  202002  20200217  1114052000      소공동   783.35   572.87   520.96
# 17   1173  202002  20200218  1114052000      소공동  1491.96   879.99   676.74
# 18   1242  202002  20200219  1114052000      소공동  1725.19  1006.93   744.14
# 19   1311  202002  20200220  1114052000      소공동  1768.46  1021.62   807.21
# 20   1380  202002  20200221  1114052000      소공동  1830.58   937.17   807.52
# 21   1449  202002  20200222  1114052000      소공동  1750.17   914.30   885.91
# 22   1518  202002  20200223  1114052000      소공동  1124.15   795.67   582.58
# 23   1587  202002  20200224  1114052000      소공동   840.88   590.50   500.63
# 24   1656  202002  20200225  1114052000      소공동  1429.60   872.51   649.99
# 25   1725  202002  20200226  1114052000      소공동  1307.63   776.27   668.73
# 26   1794  202002  20200227  1114052000      소공동  1363.65   769.34   683.98
# 27   1863  202002  20200228  1114052000      소공동  1235.04   747.10   509.35
# 28   1932  202002  20200229  1114052000      소공동  1459.54   874.09   615.89
#
#     TMST_03  TMST_04  ...   TMST_16   TMST_17   TMST_18   TMST_19  TMST_20  \
# 0    721.78   784.43  ...   7322.32   8070.40   6488.70   4890.46  4304.38
# 1    584.17   500.23  ...   5112.64   5289.63   4444.68   3807.97  3489.11
# 2    493.55   849.41  ...   9497.93  10079.19  13732.00   9208.13  5642.01
# 3    624.94   894.68  ...   9293.69  10769.58  14491.16   9826.61  5466.63
# 4    632.22   868.09  ...   9296.00  10653.31  14694.19   9179.11  5557.47
# 5    710.06   909.51  ...   9743.66  10710.38  15213.12   9461.45  5413.01
# 6    678.49   965.02  ...   9882.04  10693.40  14842.58   9871.24  5784.24
# 7    724.43   752.97  ...   6982.12   7088.43   6189.20   4293.53  3734.38
# 8    575.13   534.63  ...   5143.57   4697.92   4503.50   3507.36  3574.60
# 9    501.79   873.00  ...   9771.35  10625.11  14731.05   8891.35  5599.82
# 10   645.88   866.27  ...  10148.81  10515.64  14840.57   9950.55  5774.02
# 11   716.00   893.19  ...   9052.04  10338.38  14946.00  10032.77  5418.72
# 12   680.09   948.92  ...   9893.94  11150.12  15270.70   9333.54  5609.73
# 13   688.79   959.32  ...  10614.79  12055.73  16203.07  10400.81  6526.29
# 14   700.82   750.82  ...   8393.61   8744.00   7230.72   5159.12  4340.85
# 15   582.98   519.81  ...   5576.25   5125.55   4956.42   3690.41  3386.52
# 16   473.06   788.89  ...   8973.84   9602.94  12942.86   9052.58  5599.95
# 17   609.55   924.07  ...  10026.53  10533.89  13819.16  10144.01  5485.41
# 18   671.53   918.22  ...   9829.77  10201.15  14811.05   8845.35  5369.72
# 19   690.22   946.91  ...   9769.58  10585.06  14566.11   9490.38  5702.80
# 20   644.56   858.53  ...   9465.44  10417.17  14047.93  10270.66  5468.24
# 21   675.31   777.23  ...   6427.50   6451.17   5565.55   3909.37  3450.88
# 22   555.25   498.89  ...   4192.52   4424.45   4221.92   3480.61  2960.78
# 23   492.52   783.85  ...   7588.84   8273.56  11154.66   8738.20  4750.38
# 24   561.17   839.90  ...   7136.22   7925.49  12040.65   8407.67  4684.11
# 25   601.84   849.08  ...   7609.10   8323.75  12214.98   8078.69  4627.68
# 26   575.37   789.77  ...   7893.82   8235.01  10889.51   8287.39  4707.80
# 27   440.20   669.36  ...   7279.60   8441.16  10947.30   7502.91  4537.14
# 28   554.69   616.23  ...   4820.54   5081.33   4233.43   3249.30  3056.00
#
#     TMST_21  TMST_22  TMST_23  STD_DAY   TMST_SUM
# 0   3683.57  4002.98  2894.37        토  111317.71
# 1   3138.59  2619.49  1971.25        일   78918.43
# 2   5292.22  3828.30  2802.33        월  201506.87
# 3   5004.85  4569.69  2769.01        화  207998.46
# 4   5088.46  4343.38  2854.44        수  207158.63
# 5   5272.03  4853.03  3266.84        목  207358.02
# 6   5066.90  4660.56  3654.79        금  207568.88
# 7   3694.35  3424.27  3248.45        토  102320.61
# 8   2971.42  2498.99  1835.30        일   74025.31
# 9   5271.83  4048.62  2818.71        월  202491.24
# 10  5300.50  5103.01  3052.88        화  210002.07
# 11  5129.92  4340.04  3119.30        수  205399.36
# 12  5713.60  4679.99  3252.65        목  211880.46
# 13  5408.10  5208.85  3699.54        금  213899.52
# 14  4013.38  3852.34  2619.77        토  121052.82
# 15  3132.75  2299.17  1879.45        일   81070.12
# 16  4977.65  3938.90  2588.00        월  193363.43
# 17  5495.25  4530.84  3099.85        화  205418.52
# 18  5361.13  4892.31  3386.52        수  203813.14
# 19  5250.90  4724.01  3222.80        목  205544.20
# 20  5077.89  4766.41  3083.74        금  200541.82
# 21  3148.46  2906.09  2450.66        토   96926.07
# 22  2596.55  2074.94  1730.45        일   68485.80
# 23  3910.41  3575.37  2255.60        월  176597.46
# 24  3797.58  3265.31  2365.22        화  169452.08
# 25  3986.80  3298.04  2245.63        수  172428.98
# 26  4101.79  3754.49  2423.56        목  167766.13
# 27  3923.17  2939.17  2347.89        금  168086.37
# 28  2582.79  2200.64  1997.23        토   76185.64
#
# [29 rows x 31 columns]

# %%
# 8x4 형식의 그래프 만들기.
# x 축 : 시간대
# y 축 : 유동인구 수
# 각 특정 동에 대해서 나타내는 전체 표
# 한 그래프 당 일자 별을 나타냄

import copy

def Make_Time_Plot_HDONG(HD):
    fig, axes = plt.subplots(nrows=8,ncols=4)
    fig.set_size_inches(12, 20)
    day = 0
    x = 0
    y = 0
    mpl.rc('font', family='NanumGothic')
    
    base_df = copy.copy(HD)
    
    del base_df['index']
    base_df = base_df.reset_index(drop=True)
    del base_df['STD_YM']
    del base_df['STD_YMD']
    del base_df['HDONG_CD']
    del base_df['HDONG_NM']
    del base_df['STD_DAY']
    del base_df['TMST_SUM']
    
    base_df = base_df.T
    base_df = base_df.reset_index(drop=True)
    y_limit = [30000 for i in range(len(base_df.index))]

    while day <= 31:
        for x in range(8):
            for y in range(4):
                if day in base_df.columns:
                    if HD['STD_DAY'].values[day] == '토' or HD['STD_DAY'].values[day] == '일':
                        axes[x][y].plot(base_df.index, base_df[base_df.columns[day]], color='r')
                    elif HD['STD_DAY'].values[day] == '금':
                        axes[x][y].plot(base_df.index, base_df[base_df.columns[day]], color='orange')
                    else:
                        axes[x][y].plot(base_df.index, base_df[base_df.columns[day]], color='b')
                    axes[x][y].plot(base_df.index, y_limit)
                    axes[x][y].set_title(str(HD['STD_YMD'].values[day])+' '+str(HD['STD_DAY'].values[day]))
                    day += 1
                else:
                    day += 1
                    break
    
    plt.suptitle(str(HD.HDONG_NM.values[0]))
    plt.show()

# %%
ex = Make_Time_HDONG(2002, 0)
Make_Time_Plot_HDONG(ex)

# %%
# 8x4 형식의 그래프 만들기.
# x 축 : 시간대
# y 축 : 유동인구 수
# 각 일자에 대해서 나타내는 전체 표
# 한 그래프 당 특정 동을 나타냄

def Make_Time_Plot_Day(FullDay):
    fig, axes = plt.subplots(nrows=10,ncols=7)
    fig.set_size_inches(12, 30)
    x = 0
    y = 0
    mpl.rc('font', family='NanumGothic')
    
    if FullDay // 100 == 201902:
        base_df = copy.copy(Flow_Time_1902)
    elif FullDay // 100 == 201903:
        base_df = copy.copy(Flow_Time_1903)
    elif FullDay // 100 == 201904:
        base_df = copy.copy(Flow_Time_1904)
    elif FullDay // 100 == 201905:
        base_df = copy.copy(Flow_Time_1905)
    elif FullDay // 100 == 202002:
        base_df = copy.copy(Flow_Time_2002)
    elif FullDay // 100 == 202003:
        base_df = copy.copy(Flow_Time_2003)
    elif FullDay // 100 == 202004:
        base_df = copy.copy(Flow_Time_2004)
    elif FullDay // 100 == 202005:
        base_df = copy.copy(Flow_Time_2005)
    else:
        print('20190201 ~ 20200531')
        
    ori_df = copy.copy(base_df)
    del base_df['STD_YM']
    del base_df['STD_YMD']
    del base_df['HDONG_CD']
    del base_df['HDONG_NM']
    del base_df['STD_DAY']
    del base_df['TMST_SUM']
    
    time_list = [i for i in range(24)]
    y_limit = [10000 for i in range(len(time_list))]
    
    day = FullDay % 100
    # 1~31일 . 1일: 0~69. 2일: 69~138. ~~ ,, 행정동 갯수가 69개.
    day_HDONG = day*69 - 69
    end_day_HDONG = day*69
    
    while day_HDONG < end_day_HDONG:
        for x in range(10):
            for y in range(7):
                if day_HDONG >= end_day_HDONG:
                    break
                axes[x][y].plot(time_list, base_df.loc[day_HDONG])
                axes[x][y].plot(time_list, y_limit)
                axes[x][y].set_title(ori_df.HDONG_NM.values[day_HDONG])
                day_HDONG += 1
    
    plt.suptitle(str(FullDay)+' '+str(ori_df['STD_DAY'].values[day_HDONG-2]))
    plt.show()
    print(day_HDONG)

# %%
Make_Time_Plot_Day(20200502)
# Out:
# 138
